# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import glob, os

# %%
def extract_label(img_path):
    filename, _ = os.path.splitext(os.path.basename(img_path))
    
    subject_id, etc = filename.split('__')
    gender, lr, finger, _ = etc.split('_')
    
    gender = 0 if gender == 'M' else 1
    lr = 0 if lr =='Left' else 1
    
    if finger == 'thumb':
        finger = 0
    elif finger == 'index':
        finger = 1
    elif finger == 'middle':
        finger = 2
    elif finger == 'ring':
        finger = 3
    elif finger == 'little':
        finger = 4
        
    return np.array([subject_id, gender, lr, finger], dtype=np.uint16)

def extract_label2(img_path):
    filename, _ = os.path.splitext(os.path.basename(img_path))
    
    subject_id, etc = filename.split('__')
    gender, lr, finger, _, _ = etc.split('_')
    
    gender = 0 if gender == 'M' else 1
    lr = 0 if lr =='Left' else 1
    
    if finger == 'thumb':
        finger = 0
    elif finger == 'index':
        finger = 1
    elif finger == 'middle':
        finger = 2
    elif finger == 'ring':
        finger = 3
    elif finger == 'little':
        finger = 4
        
    return np.array([subject_id, gender, lr, finger], dtype=np.uint16)

# %%
img_list
# Out:
# ['SOCOFing_1/Real\\1516518182049-final_image.pgm',
#  'SOCOFing_1/Real\\1516518183824-final_image.pgm',
#  'SOCOFing_1/Real\\1516518185850-final_image.pgm',
#  'SOCOFing_1/Real\\1516518187396-final_image.pgm',
#  'SOCOFing_1/Real\\1516518188778-final_image.pgm',
#  'SOCOFing_1/Real\\1516518190112-final_image.pgm',
#  'SOCOFing_1/Real\\1516518191470-final_image.pgm',
#  'SOCOFing_1/Real\\1516518192989-final_image.pgm',
#  'SOCOFing_1/Real\\1516518196163-final_image.pgm',
#  'SOCOFing_1/Real\\1516518198456-final_image.pgm',
#  'SOCOFing_1/Real\\1516518200009-final_image.pgm',
#  'SOCOFing_1/Real\\1516518201232-final_image.pgm',
#  'SOCOFing_1/Real\\1516518202488-final_image.pgm',
#  'SOCOFing_1/Real\\1516518203604-final_image.pgm',
#  'SOCOFing_1/Real\\1516518204789-final_image.pgm',
#  'SOCOFing_1/Real\\1516518206102-final_image.pgm',
#  'SOCOFing_1/Real\\1516518273857-final_image.pgm',
#  'SOCOFing_1/Real\\1516518274946-final_image.pgm',
#  'SOCOFing_1/Real\\1516518275941-final_image.pgm',
#  'SOCOFing_1/Real\\1516518276877-final_image.pgm',
#  'SOCOFing_1/Real\\1516518277778-final_image.pgm',
#  'SOCOFing_1/Real\\1516518278576-final_image.pgm',
#  'SOCOFing_1/Real\\1516518279575-final_image.pgm',
#  'SOCOFing_1/Real\\1516518280370-final_image.pgm',
#  'SOCOFing_1/Real\\1516518282115-final_image.pgm',
#  'SOCOFing_1/Real\\1516518283058-final_image.pgm',
#  'SOCOFing_1/Real\\1516518283979-final_image.pgm',
#  'SOCOFing_1/Real\\1516518284769-final_image.pgm',
#  'SOCOFing_1/Real\\1516518285532-final_image.pgm',
#  'SOCOFing_1/Real\\1516518286473-final_image.pgm',
#  'SOCOFing_1/Real\\1516518287193-final_image.pgm',
#  'SOCOFing_1/Real\\1516518287962-final_image.pgm',
#  'SOCOFing_1/Real\\1516518288874-final_image.pgm',
#  'SOCOFing_1/Real\\1516518289864-final_image.pgm',
#  'SOCOFing_1/Real\\1516518290770-final_image.pgm',
#  'SOCOFing_1/Real\\1516518291754-final_image.pgm',
#  'SOCOFing_1/Real\\1516518292822-final_image.pgm',
#  'SOCOFing_1/Real\\1516518293625-final_image.pgm',
#  'SOCOFing_1/Real\\1516518294555-final_image.pgm',
#  'SOCOFing_1/Real\\1516518295242-final_image.pgm',
#  'SOCOFing_1/Real\\1516518295970-final_image.pgm',
#  'SOCOFing_1/Real\\1516518296947-final_image.pgm',
#  'SOCOFing_1/Real\\1516518297743-final_image.pgm',
#  'SOCOFing_1/Real\\1516518298633-final_image.pgm',
#  'SOCOFing_1/Real\\1516518299426-final_image.pgm',
#  'SOCOFing_1/Real\\1516518300179-final_image.pgm',
#  'SOCOFing_1/Real\\1516518328486-final_image.pgm',
#  'SOCOFing_1/Real\\1516518330952-final_image.pgm',
#  'SOCOFing_1/Real\\1516518333313-final_image.pgm',
#  'SOCOFing_1/Real\\1516518334815-final_image.pgm',
#  'SOCOFing_1/Real\\1516518336246-final_image.pgm',
#  'SOCOFing_1/Real\\1516518337206-final_image.pgm',
#  'SOCOFing_1/Real\\1516518338804-final_image.pgm',
#  'SOCOFing_1/Real\\1516518339804-final_image.pgm',
#  'SOCOFing_1/Real\\1516518341211-final_image.pgm',
#  'SOCOFing_1/Real\\1516518342547-final_image.pgm',
#  'SOCOFing_1/Real\\1516518345034-final_image.pgm',
#  'SOCOFing_1/Real\\1516518347614-final_image.pgm',
#  'SOCOFing_1/Real\\1516518348639-final_image.pgm',
#  'SOCOFing_1/Real\\1516518349888-final_image.pgm',
#  'SOCOFing_1/Real\\1516518351535-final_image.pgm',
#  'SOCOFing_1/Real\\1516518352548-final_image.pgm',
#  'SOCOFing_1/Real\\1516518388729-final_image.pgm',
#  'SOCOFing_1/Real\\1516518389761-final_image.pgm',
#  'SOCOFing_1/Real\\1516518390810-final_image.pgm',
#  'SOCOFing_1/Real\\1516518391702-final_image.pgm',
#  'SOCOFing_1/Real\\1516518392488-final_image.pgm',
#  'SOCOFing_1/Real\\1516518393442-final_image.pgm',
#  'SOCOFing_1/Real\\1516518394446-final_image.pgm',
#  'SOCOFing_1/Real\\1516518395441-final_image.pgm',
#  'SOCOFing_1/Real\\1516518396268-final_image.pgm',
#  'SOCOFing_1/Real\\1516518397306-final_image.pgm',
#  'SOCOFing_1/Real\\1516518398403-final_image.pgm',
#  'SOCOFing_1/Real\\1516518399315-final_image.pgm',
#  'SOCOFing_1/Real\\1516518400305-final_image.pgm',
#  'SOCOFing_1/Real\\1516518401220-final_image.pgm',
#  'SOCOFing_1/Real\\1516518402228-final_image.pgm',
#  'SOCOFing_1/Real\\1516518403256-final_image.pgm',
#  'SOCOFing_1/Real\\1516518404145-final_image.pgm',
#  'SOCOFing_1/Real\\1516518405185-final_image.pgm',
#  'SOCOFing_1/Real\\1516518406086-final_image.pgm',
#  'SOCOFing_1/Real\\1516518407132-final_image.pgm',
#  'SOCOFing_1/Real\\1516518408144-final_image.pgm',
#  'SOCOFing_1/Real\\1516518408998-final_image.pgm',
#  'SOCOFing_1/Real\\1516518409923-final_image.pgm',
#  'SOCOFing_1/Real\\1516518410688-final_image.pgm',
#  'SOCOFing_1/Real\\1516518411720-final_image.pgm',
#  'SOCOFing_1/Real\\1516518412471-final_image.pgm',
#  'SOCOFing_1/Real\\1516518413502-final_image.pgm',
#  'SOCOFing_1/Real\\1516518414243-final_image.pgm',
#  'SOCOFing_1/Real\\1516518415184-final_image.pgm',
#  'SOCOFing_1/Real\\1516518415949-final_image.pgm',
#  'SOCOFing_1/Real\\1516519181748-final_image.pgm',
#  'SOCOFing_1/Real\\1516519182916-final_image.pgm',
#  'SOCOFing_1/Real\\1516519184481-final_image.pgm',
#  'SOCOFing_1/Real\\1516519185917-final_image.pgm',
#  'SOCOFing_1/Real\\1516519187468-final_image.pgm',
#  'SOCOFing_1/Real\\1516519188643-final_image.pgm',
#  'SOCOFing_1/Real\\1516519189666-final_image.pgm',
#  'SOCOFing_1/Real\\1516519190658-final_image.pgm',
#  'SOCOFing_1/Real\\1516519191625-final_image.pgm',
#  'SOCOFing_1/Real\\1516519192869-final_image.pgm',
#  'SOCOFing_1/Real\\1516519193587-final_image.pgm',
#  'SOCOFing_1/Real\\1516519194836-final_image.pgm',
#  'SOCOFing_1/Real\\1516519196383-final_image.pgm',
#  'SOCOFing_1/Real\\1516519197185-final_image.pgm',
#  'SOCOFing_1/Real\\1516519198447-final_image.pgm',
#  'SOCOFing_1/Real\\1516519199448-final_image.pgm',
#  'SOCOFing_1/Real\\1516519239312-final_image.pgm',
#  'SOCOFing_1/Real\\1516519240048-final_image.pgm',
#  'SOCOFing_1/Real\\1516519240883-final_image.pgm',
#  'SOCOFing_1/Real\\1516519241695-final_image.pgm',
#  'SOCOFing_1/Real\\1516519242446-final_image.pgm',
#  'SOCOFing_1/Real\\1516519243312-final_image.pgm',
#  'SOCOFing_1/Real\\1516519244190-final_image.pgm',
#  'SOCOFing_1/Real\\1516519244952-final_image.pgm',
#  'SOCOFing_1/Real\\1516519245651-final_image.pgm',
#  'SOCOFing_1/Real\\1516519246462-final_image.pgm',
#  'SOCOFing_1/Real\\1516519247465-final_image.pgm',
#  'SOCOFing_1/Real\\1516519248205-final_image.pgm',
#  'SOCOFing_1/Real\\1516519248873-final_image.pgm',
#  'SOCOFing_1/Real\\1516519249608-final_image.pgm',
#  'SOCOFing_1/Real\\1516519250933-final_image.pgm',
#  'SOCOFing_1/Real\\1516519251629-final_image.pgm',
#  'SOCOFing_1/Real\\1516519252279-final_image.pgm',
#  'SOCOFing_1/Real\\1516519252957-final_image.pgm',
#  'SOCOFing_1/Real\\1516519254250-final_image.pgm',
#  'SOCOFing_1/Real\\1516519254678-final_image.pgm',
#  'SOCOFing_1/Real\\1516519254925-final_image.pgm',
#  'SOCOFing_1/Real\\1516519256959-final_image.pgm',
#  'SOCOFing_1/Real\\1516519257437-final_image.pgm',
#  'SOCOFing_1/Real\\1516519257664-final_image.pgm',
#  'SOCOFing_1/Real\\1516519257907-final_image.pgm',
#  'SOCOFing_1/Real\\1516519258127-final_image.pgm',
#  'SOCOFing_1/Real\\1516519258852-final_image.pgm',
#  'SOCOFing_1/Real\\1516519259191-final_image.pgm',
#  'SOCOFing_1/Real\\1516519260820-final_image.pgm',
#  'SOCOFing_1/Real\\1516519261732-final_image.pgm',
#  'SOCOFing_1/Real\\1516519262653-final_image.pgm',
#  'SOCOFing_1/Real\\1516519263495-final_image.pgm',
#  'SOCOFing_1/Real\\1516519264255-final_image.pgm',
#  'SOCOFing_1/Real\\1516519264984-final_image.pgm',
#  'SOCOFing_1/Real\\1516519265649-final_image.pgm',
#  'SOCOFing_1/Real\\1516519266356-final_image.pgm',
#  'SOCOFing_1/Real\\1516519267718-final_image.pgm',
#  'SOCOFing_1/Real\\1516519268673-final_image.pgm',
#  'SOCOFing_1/Real\\1516519320090-final_image.pgm',
#  'SOCOFing_1/Real\\1516519321478-final_image.pgm',
#  'SOCOFing_1/Real\\1516519323269-final_image.pgm',
#  'SOCOFing_1/Real\\1516519324845-final_image.pgm',
#  'SOCOFing_1/Real\\1516519326527-final_image.pgm',
#  'SOCOFing_1/Real\\1516519328367-final_image.pgm',
#  'SOCOFing_1/Real\\1516519329646-final_image.pgm',
#  'SOCOFing_1/Real\\1516519331408-final_image.pgm',
#  'SOCOFing_1/Real\\1516519333086-final_image.pgm',
#  'SOCOFing_1/Real\\1516519334096-final_image.pgm',
#  'SOCOFing_1/Real\\1516519335653-final_image.pgm',
#  'SOCOFing_1/Real\\1516519336909-final_image.pgm',
#  'SOCOFing_1/Real\\1516519338447-final_image.pgm',
#  'SOCOFing_1/Real\\1516519339502-final_image.pgm',
#  'SOCOFing_1/Real\\1516519340246-final_image.pgm',
#  'SOCOFing_1/Real\\1516519341376-final_image.pgm',
#  'SOCOFing_1/Real\\1516519375067-final_image.pgm',
#  'SOCOFing_1/Real\\1516519375995-final_image.pgm',
#  'SOCOFing_1/Real\\1516519377132-final_image.pgm',
#  'SOCOFing_1/Real\\1516519378201-final_image.pgm',
#  'SOCOFing_1/Real\\1516519379349-final_image.pgm',
#  'SOCOFing_1/Real\\1516519380365-final_image.pgm',
#  'SOCOFing_1/Real\\1516519381369-final_image.pgm',
#  'SOCOFing_1/Real\\1516519382437-final_image.pgm',
#  'SOCOFing_1/Real\\1516519383569-final_image.pgm',
#  'SOCOFing_1/Real\\1516519384765-final_image.pgm',
#  'SOCOFing_1/Real\\1516519385856-final_image.pgm',
#  'SOCOFing_1/Real\\1516519386922-final_image.pgm',
#  'SOCOFing_1/Real\\1516519388008-final_image.pgm',
#  'SOCOFing_1/Real\\1516519388972-final_image.pgm',
#  'SOCOFing_1/Real\\1516519390036-final_image.pgm',
#  'SOCOFing_1/Real\\1516519391039-final_image.pgm',
#  'SOCOFing_1/Real\\1516519391981-final_image.pgm',
#  'SOCOFing_1/Real\\1516519392943-final_image.pgm',
#  'SOCOFing_1/Real\\1516519394023-final_image.pgm',
#  'SOCOFing_1/Real\\1516519395094-final_image.pgm',
#  'SOCOFing_1/Real\\1516519396359-final_image.pgm',
#  'SOCOFing_1/Real\\1516519397295-final_image.pgm',
#  'SOCOFing_1/Real\\1516519398329-final_image.pgm',
#  'SOCOFing_1/Real\\1516519399677-final_image.pgm',
#  'SOCOFing_1/Real\\1516519400634-final_image.pgm',
#  'SOCOFing_1/Real\\1516519401888-final_image.pgm',
#  'SOCOFing_1/Real\\1516519402895-final_image.pgm',
#  'SOCOFing_1/Real\\1516519403935-final_image.pgm',
#  'SOCOFing_1/Real\\1516519404953-final_image.pgm',
#  'SOCOFing_1/Real\\1516519406114-final_image.pgm',
#  'SOCOFing_1/Real\\1516519730396-final_image.pgm',
#  'SOCOFing_1/Real\\1516519732483-final_image.pgm',
#  'SOCOFing_1/Real\\1516519733685-final_image.pgm',
#  'SOCOFing_1/Real\\1516519735015-final_image.pgm',
#  'SOCOFing_1/Real\\1516519737018-final_image.pgm',
#  'SOCOFing_1/Real\\1516519738243-final_image.pgm',
#  'SOCOFing_1/Real\\1516519739460-final_image.pgm',
#  'SOCOFing_1/Real\\1516519740914-final_image.pgm',
#  'SOCOFing_1/Real\\1516519742530-final_image.pgm',
#  'SOCOFing_1/Real\\1516519743966-final_image.pgm',
#  'SOCOFing_1/Real\\1516519745400-final_image.pgm',
#  'SOCOFing_1/Real\\1516519746368-final_image.pgm',
#  'SOCOFing_1/Real\\1516519747547-final_image.pgm',
#  'SOCOFing_1/Real\\1516519748688-final_image.pgm',
#  'SOCOFing_1/Real\\1516519749875-final_image.pgm',
#  'SOCOFing_1/Real\\1516519751414-final_image.pgm',
#  'SOCOFing_1/Real\\1516519904672-final_image.pgm',
#  'SOCOFing_1/Real\\1516519905847-final_image.pgm',
#  'SOCOFing_1/Real\\1516519906091-final_image.pgm',
#  'SOCOFing_1/Real\\1516519906336-final_image.pgm',
#  'SOCOFing_1/Real\\1516519906933-final_image.pgm',
#  'SOCOFing_1/Real\\1516519907991-final_image.pgm',
#  'SOCOFing_1/Real\\1516519908898-final_image.pgm',
#  'SOCOFing_1/Real\\1516519909837-final_image.pgm',
#  'SOCOFing_1/Real\\1516519910607-final_image.pgm',
#  'SOCOFing_1/Real\\1516519910828-final_image.pgm',
#  'SOCOFing_1/Real\\1516519911070-final_image.pgm',
#  'SOCOFing_1/Real\\1516519911525-final_image.pgm',
#  'SOCOFing_1/Real\\1516519912475-final_image.pgm',
#  'SOCOFing_1/Real\\1516519913330-final_image.pgm',
#  'SOCOFing_1/Real\\1516519914556-final_image.pgm',
#  'SOCOFing_1/Real\\1516519915570-final_image.pgm',
#  'SOCOFing_1/Real\\1516519916597-final_image.pgm',
#  'SOCOFing_1/Real\\1516519917530-final_image.pgm',
#  'SOCOFing_1/Real\\1516519918405-final_image.pgm',
#  'SOCOFing_1/Real\\1516519919425-final_image.pgm',
#  'SOCOFing_1/Real\\1516519920214-final_image.pgm',
#  'SOCOFing_1/Real\\1516519921091-final_image.pgm',
#  'SOCOFing_1/Real\\1516519921984-final_image.pgm',
#  'SOCOFing_1/Real\\1516519922809-final_image.pgm',
#  'SOCOFing_1/Real\\1516519923946-final_image.pgm',
#  'SOCOFing_1/Real\\1516519924760-final_image.pgm',
#  'SOCOFing_1/Real\\1516519925630-final_image.pgm',
#  'SOCOFing_1/Real\\1516519926401-final_image.pgm',
#  'SOCOFing_1/Real\\1516519927174-final_image.pgm',
#  'SOCOFing_1/Real\\1516519927922-final_image.pgm',
#  'SOCOFing_1/Real\\1516519928701-final_image.pgm',
#  'SOCOFing_1/Real\\1516519929402-final_image.pgm',
#  'SOCOFing_1/Real\\1516519930083-final_image.pgm',
#  'SOCOFing_1/Real\\1516519930709-final_image.pgm',
#  'SOCOFing_1/Real\\1516519965841-final_image.pgm',
#  'SOCOFing_1/Real\\1516519967710-final_image.pgm',
#  'SOCOFing_1/Real\\1516519969007-final_image.pgm',
#  'SOCOFing_1/Real\\1516519969679-final_image.pgm',
#  'SOCOFing_1/Real\\1516519971440-final_image.pgm',
#  'SOCOFing_1/Real\\1516519972228-final_image.pgm',
#  'SOCOFing_1/Real\\1516519974554-final_image.pgm',
#  'SOCOFing_1/Real\\1516519977101-final_image.pgm',
#  'SOCOFing_1/Real\\1516519978352-final_image.pgm',
#  'SOCOFing_1/Real\\1516519979688-final_image.pgm',
#  'SOCOFing_1/Real\\1516519981142-final_image.pgm',
#  'SOCOFing_1/Real\\1516519982643-final_image.pgm',
#  'SOCOFing_1/Real\\1516519983868-final_image.pgm',
#  'SOCOFing_1/Real\\1516519984689-final_image.pgm',
#  'SOCOFing_1/Real\\1516519985858-final_image.pgm',
#  'SOCOFing_1/Real\\1516519987409-final_image.pgm',
#  'SOCOFing_1/Real\\1516520011849-final_image.pgm',
#  'SOCOFing_1/Real\\1516520012084-final_image.pgm',
#  'SOCOFing_1/Real\\1516520012318-final_image.pgm',
#  'SOCOFing_1/Real\\1516520013099-final_image.pgm',
#  'SOCOFing_1/Real\\1516520014162-final_image.pgm',
#  'SOCOFing_1/Real\\1516520015021-final_image.pgm',
#  'SOCOFing_1/Real\\1516520016035-final_image.pgm',
#  'SOCOFing_1/Real\\1516520016250-final_image.pgm',
#  'SOCOFing_1/Real\\1516520016489-final_image.pgm',
#  'SOCOFing_1/Real\\1516520017011-final_image.pgm',
#  'SOCOFing_1/Real\\1516520018040-final_image.pgm',
#  'SOCOFing_1/Real\\1516520018922-final_image.pgm',
#  'SOCOFing_1/Real\\1516520019155-final_image.pgm',
#  'SOCOFing_1/Real\\1516520019410-final_image.pgm',
#  'SOCOFing_1/Real\\1516520019904-final_image.pgm',
#  'SOCOFing_1/Real\\1516520020812-final_image.pgm',
#  'SOCOFing_1/Real\\1516520021060-final_image.pgm',
#  'SOCOFing_1/Real\\1516520021314-final_image.pgm',
#  'SOCOFing_1/Real\\1516520022233-final_image.pgm',
#  'SOCOFing_1/Real\\1516520023536-final_image.pgm',
#  'SOCOFing_1/Real\\1516520024714-final_image.pgm',
#  'SOCOFing_1/Real\\1516520025945-final_image.pgm',
#  'SOCOFing_1/Real\\1516520027094-final_image.pgm',
#  'SOCOFing_1/Real\\1516520028103-final_image.pgm',
#  'SOCOFing_1/Real\\1516520029508-final_image.pgm',
#  'SOCOFing_1/Real\\1516520030507-final_image.pgm',
#  'SOCOFing_1/Real\\1516520035982-final_image.pgm',
#  'SOCOFing_1/Real\\1516520037233-final_image.pgm',
#  'SOCOFing_1/Real\\1516520038733-final_image.pgm',
#  'SOCOFing_1/Real\\1516520039945-final_image.pgm',
#  'SOCOFing_1/Real\\1516520041126-final_image.pgm',
#  'SOCOFing_1/Real\\1516520042239-final_image.pgm',
#  'SOCOFing_1/Real\\1516520043308-final_image.pgm',
#  'SOCOFing_1/Real\\1516520044324-final_image.pgm',
#  'SOCOFing_1/Real\\1516520045285-final_image.pgm',
#  'SOCOFing_1/Real\\1516520045527-final_image.pgm',
#  'SOCOFing_1/Real\\1516520045790-final_image.pgm',
#  'SOCOFing_1/Real\\1516520046049-final_image.pgm',
#  'SOCOFing_1/Real\\1516520047210-final_image.pgm',
#  'SOCOFing_1/Real\\1516520048159-final_image.pgm',
#  'SOCOFing_1/Real\\1516520049082-final_image.pgm',
#  'SOCOFing_1/Real\\1516520091556-final_image.pgm',
#  'SOCOFing_1/Real\\1516520092977-final_image.pgm',
#  'SOCOFing_1/Real\\1516520094125-final_image.pgm',
#  'SOCOFing_1/Real\\1516520095190-final_image.pgm',
#  'SOCOFing_1/Real\\1516520096325-final_image.pgm',
#  'SOCOFing_1/Real\\1516520097452-final_image.pgm',
#  'SOCOFing_1/Real\\1516520098629-final_image.pgm',
#  'SOCOFing_1/Real\\1516520099765-final_image.pgm',
#  'SOCOFing_1/Real\\1516520100920-final_image.pgm',
#  'SOCOFing_1/Real\\1516520102057-final_image.pgm',
#  'SOCOFing_1/Real\\1516520103164-final_image.pgm',
#  'SOCOFing_1/Real\\1516520104220-final_image.pgm',
#  'SOCOFing_1/Real\\1516520105322-final_image.pgm',
#  'SOCOFing_1/Real\\1516520106470-final_image.pgm',
#  'SOCOFing_1/Real\\1516520107632-final_image.pgm',
#  'SOCOFing_1/Real\\1516520108774-final_image.pgm',
#  'SOCOFing_1/Real\\1516520139573-final_image.pgm',
#  'SOCOFing_1/Real\\1516520140620-final_image.pgm',
#  'SOCOFing_1/Real\\1516520141589-final_image.pgm',
#  'SOCOFing_1/Real\\1516520142572-final_image.pgm',
#  'SOCOFing_1/Real\\1516520143525-final_image.pgm',
#  'SOCOFing_1/Real\\1516520144439-final_image.pgm',
#  'SOCOFing_1/Real\\1516520145269-final_image.pgm',
#  'SOCOFing_1/Real\\1516520146315-final_image.pgm',
#  'SOCOFing_1/Real\\1516520147292-final_image.pgm',
#  'SOCOFing_1/Real\\1516520148209-final_image.pgm',
#  'SOCOFing_1/Real\\1516520149466-final_image.pgm',
#  'SOCOFing_1/Real\\1516520150501-final_image.pgm',
#  'SOCOFing_1/Real\\1516520151535-final_image.pgm',
#  'SOCOFing_1/Real\\1516520152535-final_image.pgm',
#  'SOCOFing_1/Real\\1516520153540-final_image.pgm',
#  'SOCOFing_1/Real\\1516520154545-final_image.pgm',
#  'SOCOFing_1/Real\\1516520155565-final_image.pgm',
#  'SOCOFing_1/Real\\1516520156493-final_image.pgm',
#  'SOCOFing_1/Real\\1516520157493-final_image.pgm',
#  'SOCOFing_1/Real\\1516520158450-final_image.pgm',
#  'SOCOFing_1/Real\\1516520159773-final_image.pgm',
#  'SOCOFing_1/Real\\1516520160826-final_image.pgm',
#  'SOCOFing_1/Real\\1516520161909-final_image.pgm',
#  'SOCOFing_1/Real\\1516520162899-final_image.pgm',
#  'SOCOFing_1/Real\\1516520163928-final_image.pgm',
#  'SOCOFing_1/Real\\1516520164970-final_image.pgm',
#  'SOCOFing_1/Real\\1516520165981-final_image.pgm',
#  'SOCOFing_1/Real\\1516520166953-final_image.pgm',
#  'SOCOFing_1/Real\\1516520167885-final_image.pgm',
#  'SOCOFing_1/Real\\1516520168722-final_image.pgm',
#  'SOCOFing_1/Real\\1516520207604-final_image.pgm',
#  'SOCOFing_1/Real\\1516520209366-final_image.pgm',
#  'SOCOFing_1/Real\\1516520210852-final_image.pgm',
#  'SOCOFing_1/Real\\1516520212717-final_image.pgm',
#  'SOCOFing_1/Real\\1516520214523-final_image.pgm',
#  'SOCOFing_1/Real\\1516520215977-final_image.pgm',
#  'SOCOFing_1/Real\\1516520217445-final_image.pgm',
#  'SOCOFing_1/Real\\1516520218691-final_image.pgm',
#  'SOCOFing_1/Real\\1516520220245-final_image.pgm',
#  'SOCOFing_1/Real\\1516520223179-final_image.pgm',
#  'SOCOFing_1/Real\\1516520224116-final_image.pgm',
#  'SOCOFing_1/Real\\1516520225329-final_image.pgm',
#  'SOCOFing_1/Real\\1516520226464-final_image.pgm',
#  'SOCOFing_1/Real\\1516520227915-final_image.pgm',
#  'SOCOFing_1/Real\\1516520229119-final_image.pgm',
#  'SOCOFing_1/Real\\1516520231353-final_image.pgm',
#  'SOCOFing_1/Real\\1516520259883-final_image.pgm',
#  'SOCOFing_1/Real\\1516520260117-final_image.pgm',
#  'SOCOFing_1/Real\\1516520260353-final_image.pgm',
#  'SOCOFing_1/Real\\1516520261372-final_image.pgm',
#  'SOCOFing_1/Real\\1516520261616-final_image.pgm',
#  'SOCOFing_1/Real\\1516520261861-final_image.pgm',
#  'SOCOFing_1/Real\\1516520262764-final_image.pgm',
#  'SOCOFing_1/Real\\1516520263906-final_image.pgm',
#  'SOCOFing_1/Real\\1516520264940-final_image.pgm',
#  'SOCOFing_1/Real\\1516520265941-final_image.pgm',
#  'SOCOFing_1/Real\\1516520266999-final_image.pgm',
#  'SOCOFing_1/Real\\1516520268093-final_image.pgm',
#  'SOCOFing_1/Real\\1516520269120-final_image.pgm',
#  'SOCOFing_1/Real\\1516520270187-final_image.pgm',
#  'SOCOFing_1/Real\\1516520270429-final_image.pgm',
#  'SOCOFing_1/Real\\1516520270685-final_image.pgm',
#  'SOCOFing_1/Real\\1516520271727-final_image.pgm',
#  'SOCOFing_1/Real\\1516520272773-final_image.pgm',
#  'SOCOFing_1/Real\\1516520273909-final_image.pgm',
#  'SOCOFing_1/Real\\1516520274903-final_image.pgm',
#  'SOCOFing_1/Real\\1516520275884-final_image.pgm',
#  'SOCOFing_1/Real\\1516520276897-final_image.pgm',
#  'SOCOFing_1/Real\\1516520277895-final_image.pgm',
#  'SOCOFing_1/Real\\1516520278903-final_image.pgm',
#  'SOCOFing_1/Real\\1516520279922-final_image.pgm',
#  'SOCOFing_1/Real\\1516520280927-final_image.pgm',
#  'SOCOFing_1/Real\\1516520282195-final_image.pgm',
#  'SOCOFing_1/Real\\1516520283265-final_image.pgm',
#  'SOCOFing_1/Real\\1516520284411-final_image.pgm',
#  'SOCOFing_1/Real\\1516520285453-final_image.pgm',
#  'SOCOFing_1/Real\\1516520286498-final_image.pgm',
#  'SOCOFing_1/Real\\1516520287572-final_image.pgm',
#  'SOCOFing_1/Real\\1516520288570-final_image.pgm',
#  'SOCOFing_1/Real\\1516520289596-final_image.pgm',
#  'SOCOFing_1/Real\\1516520290598-final_image.pgm',
#  'SOCOFing_1/Real\\1516520291647-final_image.pgm',
#  'SOCOFing_1/Real\\1516521120680-final_image.pgm',
#  'SOCOFing_1/Real\\1516521122113-final_image.pgm',
#  'SOCOFing_1/Real\\1516521123872-final_image.pgm',
#  'SOCOFing_1/Real\\1516521125580-final_image.pgm',
#  'SOCOFing_1/Real\\1516521127282-final_image.pgm',
#  'SOCOFing_1/Real\\1516521128720-final_image.pgm',
#  'SOCOFing_1/Real\\1516521130154-final_image.pgm',
#  'SOCOFing_1/Real\\1516521132101-final_image.pgm',
#  'SOCOFing_1/Real\\1516521133590-final_image.pgm',
#  'SOCOFing_1/Real\\1516521135053-final_image.pgm',
#  'SOCOFing_1/Real\\1516521136465-final_image.pgm',
#  'SOCOFing_1/Real\\1516521138543-final_image.pgm',
#  'SOCOFing_1/Real\\1516521139986-final_image.pgm',
#  'SOCOFing_1/Real\\1516521141710-final_image.pgm',
#  'SOCOFing_1/Real\\1516521144548-final_image.pgm',
#  'SOCOFing_1/Real\\1516521145530-final_image.pgm',
#  'SOCOFing_1/Real\\1516521286699-final_image.pgm',
#  'SOCOFing_1/Real\\1516521287861-final_image.pgm',
#  'SOCOFing_1/Real\\1516521288930-final_image.pgm',
#  'SOCOFing_1/Real\\1516521289197-final_image.pgm',
#  'SOCOFing_1/Real\\1516521289461-final_image.pgm',
#  'SOCOFing_1/Real\\1516521290352-final_image.pgm',
#  'SOCOFing_1/Real\\1516521290606-final_image.pgm',
#  'SOCOFing_1/Real\\1516521290857-final_image.pgm',
#  'SOCOFing_1/Real\\1516521291738-final_image.pgm',
#  'SOCOFing_1/Real\\1516521292004-final_image.pgm',
#  'SOCOFing_1/Real\\1516521292234-final_image.pgm',
#  'SOCOFing_1/Real\\1516521293122-final_image.pgm',
#  'SOCOFing_1/Real\\1516521293369-final_image.pgm',
#  'SOCOFing_1/Real\\1516521293635-final_image.pgm',
#  'SOCOFing_1/Real\\1516521294523-final_image.pgm',
#  'SOCOFing_1/Real\\1516521294766-final_image.pgm',
#  'SOCOFing_1/Real\\1516521295024-final_image.pgm',
#  'SOCOFing_1/Real\\1516521295969-final_image.pgm',
#  'SOCOFing_1/Real\\1516521296218-final_image.pgm',
#  'SOCOFing_1/Real\\1516521296454-final_image.pgm',
#  'SOCOFing_1/Real\\1516521297113-final_image.pgm',
#  'SOCOFing_1/Real\\1516521297331-final_image.pgm',
#  'SOCOFing_1/Real\\1516521297582-final_image.pgm',
#  'SOCOFing_1/Real\\1516521298683-final_image.pgm',
#  'SOCOFing_1/Real\\1516521298935-final_image.pgm',
#  'SOCOFing_1/Real\\1516521299171-final_image.pgm',
#  'SOCOFing_1/Real\\1516521300059-final_image.pgm',
#  'SOCOFing_1/Real\\1516521300303-final_image.pgm',
#  'SOCOFing_1/Real\\1516521300543-final_image.pgm',
#  'SOCOFing_1/Real\\1516521301816-final_image.pgm',
#  'SOCOFing_1/Real\\1516521303187-final_image.pgm',
#  'SOCOFing_1/Real\\1516521304477-final_image.pgm',
#  'SOCOFing_1/Real\\1516521305594-final_image.pgm',
#  'SOCOFing_1/Real\\1516521306654-final_image.pgm',
#  'SOCOFing_1/Real\\1516521307717-final_image.pgm',
#  'SOCOFing_1/Real\\1516521308789-final_image.pgm',
#  'SOCOFing_1/Real\\1516521309926-final_image.pgm',
#  'SOCOFing_1/Real\\1516521311166-final_image.pgm',
#  'SOCOFing_1/Real\\1516521312763-final_image.pgm',
#  'SOCOFing_1/Real\\1516521313912-final_image.pgm',
#  'SOCOFing_1/Real\\1516521315265-final_image.pgm',
#  'SOCOFing_1/Real\\1516521316530-final_image.pgm',
#  'SOCOFing_1/Real\\1516521317669-final_image.pgm',
#  'SOCOFing_1/Real\\1516521318798-final_image.pgm',
#  'SOCOFing_1/Real\\1516521319869-final_image.pgm',
#  'SOCOFing_1/Real\\1516521321019-final_image.pgm',
#  'SOCOFing_1/Real\\1516521322076-final_image.pgm',
#  'SOCOFing_1/Real\\1516521323099-final_image.pgm',
#  'SOCOFing_1/Real\\1516521350897-final_image.pgm',
#  'SOCOFing_1/Real\\1516521352546-final_image.pgm',
#  'SOCOFing_1/Real\\1516521354123-final_image.pgm',
#  'SOCOFing_1/Real\\1516521355761-final_image.pgm',
#  'SOCOFing_1/Real\\1516521357385-final_image.pgm',
#  'SOCOFing_1/Real\\1516521358738-final_image.pgm',
#  'SOCOFing_1/Real\\1516521360165-final_image.pgm',
#  'SOCOFing_1/Real\\1516521361499-final_image.pgm',
#  'SOCOFing_1/Real\\1516521362771-final_image.pgm',
#  'SOCOFing_1/Real\\1516521364171-final_image.pgm',
#  'SOCOFing_1/Real\\1516521365606-final_image.pgm',
#  'SOCOFing_1/Real\\1516521367003-final_image.pgm',
#  'SOCOFing_1/Real\\1516521368411-final_image.pgm',
#  'SOCOFing_1/Real\\1516521369850-final_image.pgm',
#  'SOCOFing_1/Real\\1516521371246-final_image.pgm',
#  'SOCOFing_1/Real\\1516521372686-final_image.pgm',
#  'SOCOFing_1/Real\\1516521406447-final_image.pgm',
#  'SOCOFing_1/Real\\1516521406674-final_image.pgm',
#  'SOCOFing_1/Real\\1516521406910-final_image.pgm',
#  'SOCOFing_1/Real\\1516521407861-final_image.pgm',
#  'SOCOFing_1/Real\\1516521408096-final_image.pgm',
#  'SOCOFing_1/Real\\1516521408345-final_image.pgm',
#  'SOCOFing_1/Real\\1516521409258-final_image.pgm',
#  'SOCOFing_1/Real\\1516521409492-final_image.pgm',
#  'SOCOFing_1/Real\\1516521409742-final_image.pgm',
#  'SOCOFing_1/Real\\1516521410694-final_image.pgm',
#  'SOCOFing_1/Real\\1516521410928-final_image.pgm',
#  'SOCOFing_1/Real\\1516521411172-final_image.pgm',
#  'SOCOFing_1/Real\\1516521412098-final_image.pgm',
#  'SOCOFing_1/Real\\1516521412339-final_image.pgm',
#  'SOCOFing_1/Real\\1516521412601-final_image.pgm',
#  'SOCOFing_1/Real\\1516521413468-final_image.pgm',
#  'SOCOFing_1/Real\\1516521413703-final_image.pgm',
#  'SOCOFing_1/Real\\1516521414829-final_image.pgm',
#  'SOCOFing_1/Real\\1516521415060-final_image.pgm',
#  'SOCOFing_1/Real\\1516521415302-final_image.pgm',
#  'SOCOFing_1/Real\\1516521416117-final_image.pgm',
#  'SOCOFing_1/Real\\1516521416347-final_image.pgm',
#  'SOCOFing_1/Real\\1516521416620-final_image.pgm',
#  'SOCOFing_1/Real\\1516521417459-final_image.pgm',
#  'SOCOFing_1/Real\\1516521417704-final_image.pgm',
#  'SOCOFing_1/Real\\1516521417929-final_image.pgm',
#  'SOCOFing_1/Real\\1516521418787-final_image.pgm',
#  'SOCOFing_1/Real\\1516521419031-final_image.pgm',
#  'SOCOFing_1/Real\\1516521419297-final_image.pgm',
#  'SOCOFing_1/Real\\1516521420417-final_image.pgm',
#  'SOCOFing_1/Real\\1516521421522-final_image.pgm',
#  'SOCOFing_1/Real\\1516521422692-final_image.pgm',
#  'SOCOFing_1/Real\\1516521422943-final_image.pgm',
#  'SOCOFing_1/Real\\1516521423221-final_image.pgm',
#  'SOCOFing_1/Real\\1516521424082-final_image.pgm',
#  'SOCOFing_1/Real\\1516521424343-final_image.pgm',
#  'SOCOFing_1/Real\\1516521424592-final_image.pgm',
#  'SOCOFing_1/Real\\1516521425490-final_image.pgm',
#  'SOCOFing_1/Real\\1516521425719-final_image.pgm',
#  'SOCOFing_1/Real\\1516521425981-final_image.pgm',
#  'SOCOFing_1/Real\\1516521426859-final_image.pgm',
#  'SOCOFing_1/Real\\1516521427080-final_image.pgm',
#  'SOCOFing_1/Real\\1516521427292-final_image.pgm',
#  'SOCOFing_1/Real\\1516521428212-final_image.pgm',
#  'SOCOFing_1/Real\\1516521428447-final_image.pgm',
#  'SOCOFing_1/Real\\1516521428703-final_image.pgm',
#  'SOCOFing_1/Real\\1516521429615-final_image.pgm',
#  'SOCOFing_1/Real\\1516521429849-final_image.pgm',
#  'SOCOFing_1/Real\\1516521430102-final_image.pgm',
#  'SOCOFing_1/Real\\1516521431012-final_image.pgm',
#  'SOCOFing_1/Real\\1516521431247-final_image.pgm',
#  'SOCOFing_1/Real\\1516521431499-final_image.pgm',
#  'SOCOFing_1/Real\\1516521432394-final_image.pgm',
#  'SOCOFing_1/Real\\1516521432665-final_image.pgm',
#  'SOCOFing_1/Real\\1516521432894-final_image.pgm',
#  'SOCOFing_1/Real\\1516521434491-final_image.pgm',
#  'SOCOFing_1/Real\\1516521435842-final_image.pgm',
#  'SOCOFing_1/Real\\1516521437001-final_image.pgm',
#  'SOCOFing_1/Real\\1516521438273-final_image.pgm',
#  'SOCOFing_1/Real\\1516521439444-final_image.pgm',
#  'SOCOFing_1/Real\\1516521440717-final_image.pgm',
#  'SOCOFing_1/Real\\1516521442041-final_image.pgm',
#  'SOCOFing_1/Real\\1516521443211-final_image.pgm',
#  'SOCOFing_1/Real\\1516521444399-final_image.pgm',
#  'SOCOFing_1/Real\\1516521445535-final_image.pgm',
#  'SOCOFing_1/Real\\1516522179226-final_image.pgm',
#  'SOCOFing_1/Real\\1516522180396-final_image.pgm',
#  'SOCOFing_1/Real\\1516522182126-final_image.pgm',
#  'SOCOFing_1/Real\\1516522183924-final_image.pgm',
#  'SOCOFing_1/Real\\1516522185135-final_image.pgm',
#  'SOCOFing_1/Real\\1516522186264-final_image.pgm',
#  'SOCOFing_1/Real\\1516522187423-final_image.pgm',
#  'SOCOFing_1/Real\\1516522188883-final_image.pgm',
#  'SOCOFing_1/Real\\1516522190162-final_image.pgm',
#  'SOCOFing_1/Real\\1516522191407-final_image.pgm',
#  'SOCOFing_1/Real\\1516522192615-final_image.pgm',
#  'SOCOFing_1/Real\\1516522193764-final_image.pgm',
#  'SOCOFing_1/Real\\1516522194977-final_image.pgm',
#  'SOCOFing_1/Real\\1516522196197-final_image.pgm',
#  'SOCOFing_1/Real\\1516522197835-final_image.pgm',
#  'SOCOFing_1/Real\\1516522199204-final_image.pgm',
#  'SOCOFing_1/Real\\1516522281287-final_image.pgm',
#  'SOCOFing_1/Real\\1516522282401-final_image.pgm',
#  'SOCOFing_1/Real\\1516522282623-final_image.pgm',
#  'SOCOFing_1/Real\\1516522282822-final_image.pgm',
#  'SOCOFing_1/Real\\1516522283549-final_image.pgm',
#  'SOCOFing_1/Real\\1516522283785-final_image.pgm',
#  'SOCOFing_1/Real\\1516522284049-final_image.pgm',
#  'SOCOFing_1/Real\\1516522284579-final_image.pgm',
#  'SOCOFing_1/Real\\1516522285683-final_image.pgm',
#  'SOCOFing_1/Real\\1516522285919-final_image.pgm',
#  'SOCOFing_1/Real\\1516522286128-final_image.pgm',
#  'SOCOFing_1/Real\\1516522286934-final_image.pgm',
#  'SOCOFing_1/Real\\1516522287949-final_image.pgm',
#  'SOCOFing_1/Real\\1516522288938-final_image.pgm',
#  'SOCOFing_1/Real\\1516522289169-final_image.pgm',
#  'SOCOFing_1/Real\\1516522289444-final_image.pgm',
#  'SOCOFing_1/Real\\1516522290047-final_image.pgm',
#  'SOCOFing_1/Real\\1516522291060-final_image.pgm',
#  'SOCOFing_1/Real\\1516522292389-final_image.pgm',
#  'SOCOFing_1/Real\\1516522293417-final_image.pgm',
#  'SOCOFing_1/Real\\1516522294626-final_image.pgm',
#  'SOCOFing_1/Real\\1516522295878-final_image.pgm',
#  'SOCOFing_1/Real\\1516522296938-final_image.pgm',
#  'SOCOFing_1/Real\\1516522297940-final_image.pgm',
#  'SOCOFing_1/Real\\1516522298784-final_image.pgm',
#  'SOCOFing_1/Real\\1516522299796-final_image.pgm',
#  'SOCOFing_1/Real\\1516522300749-final_image.pgm',
#  'SOCOFing_1/Real\\1516522301541-final_image.pgm',
#  'SOCOFing_1/Real\\1516522302777-final_image.pgm',
#  'SOCOFing_1/Real\\1516522303912-final_image.pgm',
#  'SOCOFing_1/Real\\1516522304844-final_image.pgm',
#  'SOCOFing_1/Real\\1516522305809-final_image.pgm',
#  'SOCOFing_1/Real\\1516522306063-final_image.pgm',
#  'SOCOFing_1/Real\\1516522306328-final_image.pgm',
#  'SOCOFing_1/Real\\1516522306845-final_image.pgm',
#  'SOCOFing_1/Real\\1516522307766-final_image.pgm',
#  'SOCOFing_1/Real\\1516522308843-final_image.pgm',
#  'SOCOFing_1/Real\\1516522309728-final_image.pgm',
#  'SOCOFing_1/Real\\1516522310703-final_image.pgm',
#  'SOCOFing_1/Real\\1516522311807-final_image.pgm',
#  'SOCOFing_1/Real\\1516522355538-final_image.pgm',
#  'SOCOFing_1/Real\\1516522356717-final_image.pgm',
#  'SOCOFing_1/Real\\1516522358564-final_image.pgm',
#  'SOCOFing_1/Real\\1516522359767-final_image.pgm',
#  'SOCOFing_1/Real\\1516522361553-final_image.pgm',
#  'SOCOFing_1/Real\\1516522362752-final_image.pgm',
#  'SOCOFing_1/Real\\1516522364207-final_image.pgm',
#  'SOCOFing_1/Real\\1516522365666-final_image.pgm',
#  'SOCOFing_1/Real\\1516522367226-final_image.pgm',
#  'SOCOFing_1/Real\\1516522368241-final_image.pgm',
#  'SOCOFing_1/Real\\1516522369506-final_image.pgm',
#  'SOCOFing_1/Real\\1516522371070-final_image.pgm',
#  'SOCOFing_1/Real\\1516522372555-final_image.pgm',
#  'SOCOFing_1/Real\\1516522373528-final_image.pgm',
#  'SOCOFing_1/Real\\1516522375000-final_image.pgm',
#  'SOCOFing_1/Real\\1516522376595-final_image.pgm',
#  'SOCOFing_1/Real\\1516522430477-final_image.pgm',
#  'SOCOFing_1/Real\\1516522431490-final_image.pgm',
#  'SOCOFing_1/Real\\1516522431726-final_image.pgm',
#  'SOCOFing_1/Real\\1516522431974-final_image.pgm',
#  'SOCOFing_1/Real\\1516522432500-final_image.pgm',
#  'SOCOFing_1/Real\\1516522432718-final_image.pgm',
#  'SOCOFing_1/Real\\1516522432958-final_image.pgm',
#  'SOCOFing_1/Real\\1516522433635-final_image.pgm',
#  'SOCOFing_1/Real\\1516522433858-final_image.pgm',
#  'SOCOFing_1/Real\\1516522434098-final_image.pgm',
#  'SOCOFing_1/Real\\1516522434611-final_image.pgm',
#  'SOCOFing_1/Real\\1516522435798-final_image.pgm',
#  'SOCOFing_1/Real\\1516522436964-final_image.pgm',
#  'SOCOFing_1/Real\\1516522438055-final_image.pgm',
#  'SOCOFing_1/Real\\1516522438271-final_image.pgm',
#  'SOCOFing_1/Real\\1516522438507-final_image.pgm',
#  'SOCOFing_1/Real\\1516522439081-final_image.pgm',
#  'SOCOFing_1/Real\\1516522440124-final_image.pgm',
#  'SOCOFing_1/Real\\1516522440375-final_image.pgm',
#  'SOCOFing_1/Real\\1516522440640-final_image.pgm',
#  'SOCOFing_1/Real\\1516522442126-final_image.pgm',
#  'SOCOFing_1/Real\\1516522443085-final_image.pgm',
#  'SOCOFing_1/Real\\1516522443334-final_image.pgm',
#  'SOCOFing_1/Real\\1516522443581-final_image.pgm',
#  'SOCOFing_1/Real\\1516522444108-final_image.pgm',
#  'SOCOFing_1/Real\\1516522445052-final_image.pgm',
#  'SOCOFing_1/Real\\1516522445308-final_image.pgm',
#  'SOCOFing_1/Real\\1516522446059-final_image.pgm',
#  'SOCOFing_1/Real\\1516522446294-final_image.pgm',
#  'SOCOFing_1/Real\\1516522446545-final_image.pgm',
#  'SOCOFing_1/Real\\1516522447258-final_image.pgm',
#  'SOCOFing_1/Real\\1516522447494-final_image.pgm',
#  'SOCOFing_1/Real\\1516522447739-final_image.pgm',
#  'SOCOFing_1/Real\\1516522448297-final_image.pgm',
#  'SOCOFing_1/Real\\1516522449357-final_image.pgm',
#  'SOCOFing_1/Real\\1516522449569-final_image.pgm',
#  'SOCOFing_1/Real\\1516522449824-final_image.pgm',
#  'SOCOFing_1/Real\\1516522450538-final_image.pgm',
#  'SOCOFing_1/Real\\1516522450795-final_image.pgm',
#  'SOCOFing_1/Real\\1516522451035-final_image.pgm',
#  'SOCOFing_1/Real\\1516522451768-final_image.pgm',
#  'SOCOFing_1/Real\\1516522453279-final_image.pgm',
#  'SOCOFing_1/Real\\1516522454251-final_image.pgm',
#  'SOCOFing_1/Real\\1516522454495-final_image.pgm',
#  'SOCOFing_1/Real\\1516522454750-final_image.pgm',
#  'SOCOFing_1/Real\\1516522455477-final_image.pgm',
#  'SOCOFing_1/Real\\1516522456450-final_image.pgm',
#  'SOCOFing_1/Real\\1516522457386-final_image.pgm',
#  'SOCOFing_1/Real\\1516522458397-final_image.pgm',
#  'SOCOFing_1/Real\\1516522459381-final_image.pgm',
#  'SOCOFing_1/Real\\1516522460366-final_image.pgm',
#  'SOCOFing_1/Real\\1516522461341-final_image.pgm',
#  'SOCOFing_1/Real\\1516522462298-final_image.pgm',
#  'SOCOFing_1/Real\\1516526148182-final_image.pgm',
#  'SOCOFing_1/Real\\1516526149386-final_image.pgm',
#  'SOCOFing_1/Real\\1516526150481-final_image.pgm',
#  'SOCOFing_1/Real\\1516526151499-final_image.pgm',
#  'SOCOFing_1/Real\\1516526153236-final_image.pgm',
#  'SOCOFing_1/Real\\1516526155242-final_image.pgm',
#  'SOCOFing_1/Real\\1516526156327-final_image.pgm',
#  'SOCOFing_1/Real\\1516526157367-final_image.pgm',
#  'SOCOFing_1/Real\\1516526158304-final_image.pgm',
#  'SOCOFing_1/Real\\1516526159084-final_image.pgm',
#  'SOCOFing_1/Real\\1516526159984-final_image.pgm',
#  'SOCOFing_1/Real\\1516526160752-final_image.pgm',
#  'SOCOFing_1/Real\\1516526161275-final_image.pgm',
#  'SOCOFing_1/Real\\1516526161514-final_image.pgm',
#  'SOCOFing_1/Real\\1516526161755-final_image.pgm',
#  'SOCOFing_1/Real\\1516526162011-final_image.pgm',
#  'SOCOFing_1/Real\\1516526162693-final_image.pgm',
#  'SOCOFing_1/Real\\1516526163708-final_image.pgm',
#  'SOCOFing_1/Real\\1516526164466-final_image.pgm',
#  'SOCOFing_1/Real\\1516526165222-final_image.pgm',
#  'SOCOFing_1/Real\\1516526166126-final_image.pgm',
#  'SOCOFing_1/Real\\1516526167040-final_image.pgm',
#  'SOCOFing_1/Real\\1516526167766-final_image.pgm',
#  'SOCOFing_1/Real\\1516526168720-final_image.pgm',
#  'SOCOFing_1/Real\\1516526169776-final_image.pgm',
#  'SOCOFing_1/Real\\1516526170550-final_image.pgm',
#  'SOCOFing_1/Real\\1516526171403-final_image.pgm',
#  'SOCOFing_1/Real\\1516526172320-final_image.pgm',
#  'SOCOFing_1/Real\\1516526173317-final_image.pgm',
#  'SOCOFing_1/Real\\1516526175566-final_image.pgm',
#  'SOCOFing_1/Real\\1516526176280-final_image.pgm',
#  'SOCOFing_1/Real\\1516526177162-final_image.pgm',
#  'SOCOFing_1/Real\\1516526178129-final_image.pgm',
#  'SOCOFing_1/Real\\1516526178811-final_image.pgm',
#  'SOCOFing_1/Real\\1516526211477-final_image.pgm',
#  'SOCOFing_1/Real\\1516526211700-final_image.pgm',
#  'SOCOFing_1/Real\\1516526211974-final_image.pgm',
#  'SOCOFing_1/Real\\1516526212240-final_image.pgm',
#  'SOCOFing_1/Real\\1516526213052-final_image.pgm',
#  'SOCOFing_1/Real\\1516526214052-final_image.pgm',
#  'SOCOFing_1/Real\\1516526214866-final_image.pgm',
#  'SOCOFing_1/Real\\1516526215694-final_image.pgm',
#  'SOCOFing_1/Real\\1516526216482-final_image.pgm',
#  'SOCOFing_1/Real\\1516526217268-final_image.pgm',
#  'SOCOFing_1/Real\\1516526217983-final_image.pgm',
#  'SOCOFing_1/Real\\1516526218706-final_image.pgm',
#  'SOCOFing_1/Real\\1516526219478-final_image.pgm',
#  'SOCOFing_1/Real\\1516526220349-final_image.pgm',
#  'SOCOFing_1/Real\\1516526221082-final_image.pgm',
#  'SOCOFing_1/Real\\1516526221780-final_image.pgm',
#  'SOCOFing_1/Real\\1516526222522-final_image.pgm',
#  'SOCOFing_1/Real\\1516526223252-final_image.pgm',
#  'SOCOFing_1/Real\\1516526223966-final_image.pgm',
#  'SOCOFing_1/Real\\1516526224657-final_image.pgm',
#  'SOCOFing_1/Real\\1516526225432-final_image.pgm',
#  'SOCOFing_1/Real\\1516526226159-final_image.pgm',
#  'SOCOFing_1/Real\\1516526226391-final_image.pgm',
#  'SOCOFing_1/Real\\1516526226648-final_image.pgm',
#  'SOCOFing_1/Real\\1516526226876-final_image.pgm',
#  'SOCOFing_1/Real\\1516526227111-final_image.pgm',
#  'SOCOFing_1/Real\\1516526227808-final_image.pgm',
#  'SOCOFing_1/Real\\1516526228780-final_image.pgm',
#  'SOCOFing_1/Real\\1516526229589-final_image.pgm',
#  'SOCOFing_1/Real\\1516526230377-final_image.pgm',
#  'SOCOFing_1/Real\\1516526230619-final_image.pgm',
#  'SOCOFing_1/Real\\1516526230845-final_image.pgm',
#  'SOCOFing_1/Real\\1516526231089-final_image.pgm',
#  'SOCOFing_1/Real\\1516526231319-final_image.pgm',
#  'SOCOFing_1/Real\\1516526231563-final_image.pgm',
#  'SOCOFing_1/Real\\1516526232068-final_image.pgm',
#  'SOCOFing_1/Real\\1516526232297-final_image.pgm',
#  'SOCOFing_1/Real\\1516526232541-final_image.pgm',
#  'SOCOFing_1/Real\\1516526232766-final_image.pgm',
#  'SOCOFing_1/Real\\1516526232982-final_image.pgm',
#  'SOCOFing_1/Real\\1516526233228-final_image.pgm',
#  'SOCOFing_1/Real\\1516526233958-final_image.pgm',
#  'SOCOFing_1/Real\\1516526234917-final_image.pgm',
#  'SOCOFing_1/Real\\1516526235664-final_image.pgm',
#  'SOCOFing_1/Real\\1516526236469-final_image.pgm',
#  'SOCOFing_1/Real\\1516526237461-final_image.pgm',
#  'SOCOFing_1/Real\\1516526238336-final_image.pgm',
#  'SOCOFing_1/Real\\1516526238573-final_image.pgm',
#  'SOCOFing_1/Real\\1516526238793-final_image.pgm',
#  'SOCOFing_1/Real\\1516526239012-final_image.pgm',
#  'SOCOFing_1/Real\\1516526239223-final_image.pgm',
#  'SOCOFing_1/Real\\1516526239475-final_image.pgm',
#  'SOCOFing_1/Real\\1516526916327-final_image.pgm',
#  'SOCOFing_1/Real\\1516526916554-final_image.pgm',
#  'SOCOFing_1/Real\\1516526916812-final_image.pgm',
#  'SOCOFing_1/Real\\1516526918031-final_image.pgm',
#  'SOCOFing_1/Real\\1516526919361-final_image.pgm',
#  'SOCOFing_1/Real\\1516526920633-final_image.pgm',
#  'SOCOFing_1/Real\\1516526921918-final_image.pgm',
#  'SOCOFing_1/Real\\1516526923151-final_image.pgm',
#  'SOCOFing_1/Real\\1516526923387-final_image.pgm',
#  'SOCOFing_1/Real\\1516526923640-final_image.pgm',
#  'SOCOFing_1/Real\\1516526924467-final_image.pgm',
#  'SOCOFing_1/Real\\1516526925667-final_image.pgm',
#  'SOCOFing_1/Real\\1516526926876-final_image.pgm',
#  'SOCOFing_1/Real\\1516526927096-final_image.pgm',
#  'SOCOFing_1/Real\\1516526927301-final_image.pgm',
#  'SOCOFing_1/Real\\1516526928241-final_image.pgm',
#  'SOCOFing_1/Real\\1516526928473-final_image.pgm',
#  'SOCOFing_1/Real\\1516526928712-final_image.pgm',
#  'SOCOFing_1/Real\\1516526930311-final_image.pgm',
#  'SOCOFing_1/Real\\1516526931506-final_image.pgm',
#  'SOCOFing_1/Real\\1516526932718-final_image.pgm',
#  'SOCOFing_1/Real\\1516526933947-final_image.pgm',
#  'SOCOFing_1/Real\\1516526935103-final_image.pgm',
#  'SOCOFing_1/Real\\1516526936380-final_image.pgm',
#  'SOCOFing_1/Real\\1516526937563-final_image.pgm',
#  'SOCOFing_1/Real\\1516526938718-final_image.pgm',
#  'SOCOFing_1/Real\\1516526939922-final_image.pgm',
#  'SOCOFing_1/Real\\1516526941087-final_image.pgm',
#  'SOCOFing_1/Real\\1516526943323-final_image.pgm',
#  'SOCOFing_1/Real\\1516526944540-final_image.pgm',
#  'SOCOFing_1/Real\\1516526945782-final_image.pgm',
#  'SOCOFing_1/Real\\1516526946955-final_image.pgm',
#  'SOCOFing_1/Real\\1516526948215-final_image.pgm',
#  'SOCOFing_1/Real\\1516526949379-final_image.pgm',
#  'SOCOFing_1/Real\\1516526950571-final_image.pgm',
#  'SOCOFing_1/Real\\1516526951740-final_image.pgm',
#  'SOCOFing_1/Real\\1516526952944-final_image.pgm',
#  'SOCOFing_1/Real\\1516526954126-final_image.pgm',
#  'SOCOFing_1/Real\\1516527275639-final_image.pgm',
#  'SOCOFing_1/Real\\1516527275862-final_image.pgm',
#  'SOCOFing_1/Real\\1516527276104-final_image.pgm',
#  'SOCOFing_1/Real\\1516527276383-final_image.pgm',
#  'SOCOFing_1/Real\\1516527277440-final_image.pgm',
#  'SOCOFing_1/Real\\1516527277700-final_image.pgm',
#  'SOCOFing_1/Real\\1516527277945-final_image.pgm',
#  'SOCOFing_1/Real\\1516527278862-final_image.pgm',
#  'SOCOFing_1/Real\\1516527279091-final_image.pgm',
#  'SOCOFing_1/Real\\1516527279335-final_image.pgm',
#  'SOCOFing_1/Real\\1516527280227-final_image.pgm',
#  'SOCOFing_1/Real\\1516527280467-final_image.pgm',
#  'SOCOFing_1/Real\\1516527280751-final_image.pgm',
#  'SOCOFing_1/Real\\1516527281689-final_image.pgm',
#  'SOCOFing_1/Real\\1516527281908-final_image.pgm',
#  'SOCOFing_1/Real\\1516527282182-final_image.pgm',
#  'SOCOFing_1/Real\\1516527283206-final_image.pgm',
#  'SOCOFing_1/Real\\1516527283431-final_image.pgm',
#  'SOCOFing_1/Real\\1516527283641-final_image.pgm',
#  'SOCOFing_1/Real\\1516527284560-final_image.pgm',
#  'SOCOFing_1/Real\\1516527284816-final_image.pgm',
#  'SOCOFing_1/Real\\1516527285054-final_image.pgm',
#  'SOCOFing_1/Real\\1516527285951-final_image.pgm',
#  'SOCOFing_1/Real\\1516527286207-final_image.pgm',
#  'SOCOFing_1/Real\\1516527286474-final_image.pgm',
#  'SOCOFing_1/Real\\1516527287368-final_image.pgm',
#  'SOCOFing_1/Real\\1516527287626-final_image.pgm',
#  'SOCOFing_1/Real\\1516527287878-final_image.pgm',
#  'SOCOFing_1/Real\\1516527288749-final_image.pgm',
#  'SOCOFing_1/Real\\1516527289007-final_image.pgm',
#  'SOCOFing_1/Real\\1516527289254-final_image.pgm',
#  'SOCOFing_1/Real\\1516527291170-final_image.pgm',
#  'SOCOFing_1/Real\\1516527291398-final_image.pgm',
#  'SOCOFing_1/Real\\1516527291648-final_image.pgm',
#  'SOCOFing_1/Real\\1516527292584-final_image.pgm',
#  'SOCOFing_1/Real\\1516527292842-final_image.pgm',
#  'SOCOFing_1/Real\\1516527293087-final_image.pgm',
#  'SOCOFing_1/Real\\1516527294047-final_image.pgm',
#  'SOCOFing_1/Real\\1516527294252-final_image.pgm',
#  'SOCOFing_1/Real\\1516527294515-final_image.pgm',
#  'SOCOFing_1/Real\\1516527295442-final_image.pgm',
#  'SOCOFing_1/Real\\1516527295682-final_image.pgm',
#  'SOCOFing_1/Real\\1516527295894-final_image.pgm',
#  'SOCOFing_1/Real\\1516527296814-final_image.pgm',
#  'SOCOFing_1/Real\\1516527298095-final_image.pgm',
#  'SOCOFing_1/Real\\1516527298356-final_image.pgm',
#  'SOCOFing_1/Real\\1516527298614-final_image.pgm',
#  'SOCOFing_1/Real\\1516527299501-final_image.pgm',
#  'SOCOFing_1/Real\\1516527299752-final_image.pgm',
#  'SOCOFing_1/Real\\1516527299996-final_image.pgm',
#  'SOCOFing_1/Real\\1516527300882-final_image.pgm',
#  'SOCOFing_1/Real\\1516527301142-final_image.pgm',
#  'SOCOFing_1/Real\\1516527301386-final_image.pgm',
#  'SOCOFing_1/Real\\1516527302322-final_image.pgm',
#  'SOCOFing_1/Real\\1516527302581-final_image.pgm',
#  'SOCOFing_1/Real\\1516527302847-final_image.pgm',
#  'SOCOFing_1/Real\\1516527303752-final_image.pgm',
#  'SOCOFing_1/Real\\1516527303989-final_image.pgm',
#  'SOCOFing_1/Real\\1516527304236-final_image.pgm',
#  'SOCOFing_1/Real\\1516527305862-final_image.pgm',
#  'SOCOFing_1/Real\\1516527307170-final_image.pgm',
#  'SOCOFing_1/Real\\1516527307417-final_image.pgm',
#  'SOCOFing_1/Real\\1516527307675-final_image.pgm',
#  'SOCOFing_1/Real\\1516527308692-final_image.pgm',
#  'SOCOFing_1/Real\\1516527310010-final_image.pgm',
#  'SOCOFing_1/Real\\1516527311301-final_image.pgm',
#  'SOCOFing_1/Real\\1516527312629-final_image.pgm',
#  'SOCOFing_1/Real\\1516527314195-final_image.pgm',
#  'SOCOFing_1/Real\\1516527315488-final_image.pgm',
#  'SOCOFing_1/Real\\1516527317264-final_image.pgm',
#  'SOCOFing_1/Real\\1516527318622-final_image.pgm',
#  'SOCOFing_1/Real\\1516527572445-final_image.pgm',
#  'SOCOFing_1/Real\\1516527572677-final_image.pgm',
#  'SOCOFing_1/Real\\1516527572918-final_image.pgm',
#  'SOCOFing_1/Real\\1516527573753-final_image.pgm',
#  'SOCOFing_1/Real\\1516527574712-final_image.pgm',
#  'SOCOFing_1/Real\\1516527574930-final_image.pgm',
#  'SOCOFing_1/Real\\1516527575185-final_image.pgm',
#  'SOCOFing_1/Real\\1516527576010-final_image.pgm',
#  'SOCOFing_1/Real\\1516527577039-final_image.pgm',
#  'SOCOFing_1/Real\\1516527578048-final_image.pgm',
#  'SOCOFing_1/Real\\1516527579054-final_image.pgm',
#  'SOCOFing_1/Real\\1516527580003-final_image.pgm',
#  'SOCOFing_1/Real\\1516527580946-final_image.pgm',
#  'SOCOFing_1/Real\\1516527581177-final_image.pgm',
#  'SOCOFing_1/Real\\1516527581413-final_image.pgm',
#  'SOCOFing_1/Real\\1516527582196-final_image.pgm',
#  'SOCOFing_1/Real\\1516527583541-final_image.pgm',
#  'SOCOFing_1/Real\\1516527584527-final_image.pgm',
#  'SOCOFing_1/Real\\1516527585349-final_image.pgm',
#  'SOCOFing_1/Real\\1516527586161-final_image.pgm',
#  'SOCOFing_1/Real\\1516527587086-final_image.pgm',
#  'SOCOFing_1/Real\\1516527587830-final_image.pgm',
#  'SOCOFing_1/Real\\1516527588627-final_image.pgm',
#  'SOCOFing_1/Real\\1516527589433-final_image.pgm',
#  'SOCOFing_1/Real\\1516527590250-final_image.pgm',
#  'SOCOFing_1/Real\\1516527591030-final_image.pgm',
#  'SOCOFing_1/Real\\1516527592309-final_image.pgm',
#  'SOCOFing_1/Real\\1516527593190-final_image.pgm',
#  'SOCOFing_1/Real\\1516527593949-final_image.pgm',
#  'SOCOFing_1/Real\\1516527594746-final_image.pgm',
#  'SOCOFing_1/Real\\1516527595639-final_image.pgm',
#  'SOCOFing_1/Real\\1516527596370-final_image.pgm',
#  'SOCOFing_1/Real\\1516527597335-final_image.pgm',
#  'SOCOFing_1/Real\\1516527598117-final_image.pgm',
#  'SOCOFing_1/Real\\1516527599051-final_image.pgm',
#  'SOCOFing_1/Real\\1516527599835-final_image.pgm',
#  'SOCOFing_1/Real\\1516527918578-final_image.pgm',
#  'SOCOFing_1/Real\\1516527918826-final_image.pgm',
#  'SOCOFing_1/Real\\1516527919059-final_image.pgm',
#  'SOCOFing_1/Real\\1516527919303-final_image.pgm',
#  'SOCOFing_1/Real\\1516527920322-final_image.pgm',
#  'SOCOFing_1/Real\\1516527920553-final_image.pgm',
#  'SOCOFing_1/Real\\1516527920813-final_image.pgm',
#  'SOCOFing_1/Real\\1516527921644-final_image.pgm',
#  'SOCOFing_1/Real\\1516527921885-final_image.pgm',
#  'SOCOFing_1/Real\\1516527922129-final_image.pgm',
#  'SOCOFing_1/Real\\1516527923039-final_image.pgm',
#  'SOCOFing_1/Real\\1516527923267-final_image.pgm',
#  'SOCOFing_1/Real\\1516527923522-final_image.pgm',
#  'SOCOFing_1/Real\\1516527924259-final_image.pgm',
#  'SOCOFing_1/Real\\1516527924492-final_image.pgm',
#  'SOCOFing_1/Real\\1516527924749-final_image.pgm',
#  'SOCOFing_1/Real\\1516527925509-final_image.pgm',
#  'SOCOFing_1/Real\\1516527925770-final_image.pgm',
#  'SOCOFing_1/Real\\1516527925998-final_image.pgm',
#  'SOCOFing_1/Real\\1516527926768-final_image.pgm',
#  'SOCOFing_1/Real\\1516527926994-final_image.pgm',
#  'SOCOFing_1/Real\\1516527927984-final_image.pgm',
#  'SOCOFing_1/Real\\1516527928236-final_image.pgm',
#  'SOCOFing_1/Real\\1516527929222-final_image.pgm',
#  'SOCOFing_1/Real\\1516527929441-final_image.pgm',
#  'SOCOFing_1/Real\\1516527929648-final_image.pgm',
#  'SOCOFing_1/Real\\1516527930418-final_image.pgm',
#  'SOCOFing_1/Real\\1516527930639-final_image.pgm',
#  'SOCOFing_1/Real\\1516527930882-final_image.pgm',
#  'SOCOFing_1/Real\\1516527932674-final_image.pgm',
#  'SOCOFing_1/Real\\1516527932875-final_image.pgm',
#  'SOCOFing_1/Real\\1516527933108-final_image.pgm',
#  'SOCOFing_1/Real\\1516527933839-final_image.pgm',
#  'SOCOFing_1/Real\\1516527934104-final_image.pgm',
#  'SOCOFing_1/Real\\1516527934373-final_image.pgm',
#  'SOCOFing_1/Real\\1516527934978-final_image.pgm',
#  'SOCOFing_1/Real\\1516527935200-final_image.pgm',
#  'SOCOFing_1/Real\\1516527935443-final_image.pgm',
#  'SOCOFing_1/Real\\1516527936165-final_image.pgm',
#  'SOCOFing_1/Real\\1516527936428-final_image.pgm',
#  'SOCOFing_1/Real\\1516527936651-final_image.pgm',
#  'SOCOFing_1/Real\\1516527937391-final_image.pgm',
#  'SOCOFing_1/Real\\1516527937636-final_image.pgm',
#  'SOCOFing_1/Real\\1516527937884-final_image.pgm',
#  'SOCOFing_1/Real\\1516527938674-final_image.pgm',
#  'SOCOFing_1/Real\\1516527938899-final_image.pgm',
#  'SOCOFing_1/Real\\1516527939142-final_image.pgm',
#  'SOCOFing_1/Real\\1516527939916-final_image.pgm',
#  'SOCOFing_1/Real\\1516527940944-final_image.pgm',
#  'SOCOFing_1/Real\\1516527942006-final_image.pgm',
#  'SOCOFing_1/Real\\1516527942251-final_image.pgm',
#  'SOCOFing_1/Real\\1516527942490-final_image.pgm',
#  'SOCOFing_1/Real\\1516527943203-final_image.pgm',
#  'SOCOFing_1/Real\\1516527943437-final_image.pgm',
#  'SOCOFing_1/Real\\1516527943675-final_image.pgm',
#  'SOCOFing_1/Real\\1516527947740-final_image.pgm',
#  'SOCOFing_1/Real\\1516527948857-final_image.pgm',
#  'SOCOFing_1/Real\\1516527949802-final_image.pgm',
#  'SOCOFing_1/Real\\1516527950842-final_image.pgm',
#  'SOCOFing_1/Real\\1516527952326-final_image.pgm',
#  'SOCOFing_1/Real\\1516527953411-final_image.pgm',
#  'SOCOFing_1/Real\\1516527954387-final_image.pgm',
#  'SOCOFing_1/Real\\1516527955501-final_image.pgm',
#  'SOCOFing_1/Real\\1516527956569-final_image.pgm',
#  'SOCOFing_1/Real\\1516527957624-final_image.pgm',
#  'SOCOFing_1/Real\\1516528238826-final_image.pgm',
#  'SOCOFing_1/Real\\1516528239060-final_image.pgm',
#  'SOCOFing_1/Real\\1516528239335-final_image.pgm',
#  'SOCOFing_1/Real\\1516528239609-final_image.pgm',
#  'SOCOFing_1/Real\\1516528239904-final_image.pgm',
#  'SOCOFing_1/Real\\1516528241125-final_image.pgm',
#  'SOCOFing_1/Real\\1516528241363-final_image.pgm',
#  'SOCOFing_1/Real\\1516528241576-final_image.pgm',
#  'SOCOFing_1/Real\\1516528242548-final_image.pgm',
#  'SOCOFing_1/Real\\1516528242793-final_image.pgm',
#  'SOCOFing_1/Real\\1516528243050-final_image.pgm',
#  'SOCOFing_1/Real\\1516528244076-final_image.pgm',
#  'SOCOFing_1/Real\\1516528244314-final_image.pgm',
#  'SOCOFing_1/Real\\1516528244575-final_image.pgm',
#  'SOCOFing_1/Real\\1516528245585-final_image.pgm',
#  'SOCOFing_1/Real\\1516528245817-final_image.pgm',
#  'SOCOFing_1/Real\\1516528246052-final_image.pgm',
#  'SOCOFing_1/Real\\1516528247067-final_image.pgm',
#  'SOCOFing_1/Real\\1516528247314-final_image.pgm',
#  'SOCOFing_1/Real\\1516528248521-final_image.pgm',
#  'SOCOFing_1/Real\\1516528248754-final_image.pgm',
#  'SOCOFing_1/Real\\1516528249012-final_image.pgm',
#  'SOCOFing_1/Real\\1516528249892-final_image.pgm',
#  'SOCOFing_1/Real\\1516528250142-final_image.pgm',
#  'SOCOFing_1/Real\\1516528250414-final_image.pgm',
#  'SOCOFing_1/Real\\1516528251289-final_image.pgm',
#  'SOCOFing_1/Real\\1516528251547-final_image.pgm',
#  'SOCOFing_1/Real\\1516528252706-final_image.pgm',
#  'SOCOFing_1/Real\\1516528252957-final_image.pgm',
#  'SOCOFing_1/Real\\1516528253188-final_image.pgm',
#  'SOCOFing_1/Real\\1516528254434-final_image.pgm',
#  'SOCOFing_1/Real\\1516528254677-final_image.pgm',
#  'SOCOFing_1/Real\\1516528254925-final_image.pgm',
#  'SOCOFing_1/Real\\1516528255856-final_image.pgm',
#  'SOCOFing_1/Real\\1516528256109-final_image.pgm',
#  'SOCOFing_1/Real\\1516528256376-final_image.pgm',
#  'SOCOFing_1/Real\\1516528257249-final_image.pgm',
#  ...]

# %%
img_list = sorted(glob.glob('SOCOFing_1/Real/*.pgm'))
print(len(img_list))

imgs = np.empty((len(img_list), 96, 96), dtype=np.uint8)
labels = np.empty((len(img_list), 4), dtype=np.uint16)

for i, img_path in enumerate(img_list):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (96, 96))
    imgs[i] = img
    
    # subject_id, gender, lr, finger
#     labels[i] = extract_label(img_path)
#     
np.save('dataset/x_real.npy', imgs)
# np.save('dataset/y_real.npy', labels)

plt.figure(figsize=(1, 1))
# plt.title(labels[-1])
plt.imshow(imgs[-1], cmap='gray')
# Out:
# 3917

# %%
img_list = sorted(glob.glob('SOCOFing/Real/*.BMP'))
print(len(img_list))

imgs = np.empty((len(img_list), 96, 96), dtype=np.uint8)
labels = np.empty((len(img_list), 4), dtype=np.uint16)

for i, img_path in enumerate(img_list):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (96, 96))
    imgs[i] = img
    
    # subject_id, gender, lr, finger
    labels[i] = extract_label(img_path)
    
np.save('dataset/x_real.npy', imgs)
np.save('dataset/y_real.npy', labels)

plt.figure(figsize=(1, 1))
plt.title(labels[-1])
plt.imshow(imgs[-1], cmap='gray')

# %%
plt.figure(figsize=(1, 1))
plt.title(labels[-1])
plt.imshow(imgs[1], cmap='gray')

# %%
img_list = sorted(glob.glob('SOCOFing/Altered/Altered-Easy/*.BMP'))
print(len(img_list))

imgs = np.empty((len(img_list), 96, 96), dtype=np.uint8)
labels = np.empty((len(img_list), 4), dtype=np.uint16)

for i, img_path in enumerate(img_list):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (96, 96))
    imgs[i] = img
    
    # subject_id, gender, lr, finger
    labels[i] = extract_label2(img_path)
    
np.save('dataset/x_easy.npy', imgs)
np.save('dataset/y_easy.npy', labels)

plt.figure(figsize=(1, 1))
plt.show()
plt.title(labels[-1])
plt.imshow(imgs[-1], cmap='gray')

# %%
img_list = sorted(glob.glob('SOCOFing/Altered/Altered-Medium/*.BMP'))
print(len(img_list))

imgs = np.empty((len(img_list), 96, 96), dtype=np.uint8)
labels = np.empty((len(img_list), 4), dtype=np.uint16)

for i, img_path in enumerate(img_list):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (96, 96))
    imgs[i] = img
    
    # subject_id, gender, lr, finger
    labels[i] = extract_label2(img_path)
    
np.save('dataset/x_medium.npy', imgs)
np.save('dataset/y_medium.npy', labels)

plt.figure(figsize=(1, 1))
plt.title(labels[-1])
plt.imshow(imgs[0], cmap='gray')

# %%
img_list = sorted(glob.glob('SOCOFing/Altered/Altered-Hard/*.BMP'))
print(len(img_list))

imgs = np.empty((len(img_list), 96, 96), dtype=np.uint8)
labels = np.empty((len(img_list), 4), dtype=np.uint16)

for i, img_path in enumerate(img_list):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (96, 96))
    imgs[i] = img
    
    # subject_id, gender, lr, finger
    labels[i] = extract_label2(img_path)
    
np.save('dataset/x_hard.npy', imgs)
np.save('dataset/y_hard.npy', labels)

plt.figure(figsize=(1, 1))
plt.title(labels[-1])
plt.imshow(imgs[-1], cmap='gray')
